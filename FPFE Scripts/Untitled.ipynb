# %%
import CAC
import FiOps_Portals as Portals
import FPFE 
import M1
import M2
import M3
import NTP
import FiOps_Functions as Funcs

# %%
#! Python27
# -*- coding: utf-8 -*-
"""
Created on Mon Sep 19 09:48:41 2016
@author: nseelam

Portals Menu. This is the front end of what the user will see. Based on the user's Portal option, the back end 
functions/procedures will run.

- FiOps Portals contains the various functionalities of this tool.
- FiOps Functions contains a list of procedures defined as a function, for easy readability and access.
"""

if __name__ == '__main__':
    
    print 'Welcome to FiOps Python Portal'
    print '\n'
    print 'Please begin by connecting to Sungevity\'s Database'
    cnx = Funcs.sql_fiops_connect()
    
    Active = True    
    while Active:
        print '\n'
        print 'Portals Menu:'
      
        print '1. Kina Milestone Submission'
        print '2. Data Upload File Creation'
        print '3. Exit'
        print '\n'
        
        while True:
            try:
                number = int(raw_input('Please enter the number associated with a task to proceed: '))
                if (number >=1 and number <=3):
                    break
                else:
                    print "Not a valid input. Please try again."
            except(TypeError, ValueError):
                print "Not an integer. Please try again."

        if number == 1:
            Portals.Kina_Submission_Portal(cnx)
        if number == 2:
            Portals.Kina_Upload_Portal(cnx)
        if number == 3:
            print 'Exitting...'
            Active = False
    
    cnx.close()
    
    exit()
# Out:
# Welcome to FiOps Python Portal
#
#
# Please begin by connecting to Sungevity's Database
# Please enter your Sungevity username: nseelam
#
#
# Please enter your Database Password:
# Note: Please copy and paste your password, by right click pasting. Ctrl - V does not work in the Command Prompt
# ········
#
#
# Portals Menu:
# 1. Kina Milestone Submission
# 2. Data Upload File Creation
# 3. Exit
#
#
# Please enter the number associated with a task to proceed: 1
#
#
# Welcome to Kina'ole FPFE Portal
#
#
# Is this process being executed for a Milestone Submission?
# 1. Yes
# 2. No
#
#
# Please enter the number associated with your choice of Yes or No: 2
#
#
# Please select a Milestone
# 1. CAC
# 2. NTP
# 3. M1
# 4. M2
# 5. M3
#
#
# Please enter the number associated with the Milestone: 2
# Please enter desired filename for NTP Submission File
# NeeAmmaNTP
# Query completed in 5.2940 seconds
# 7
# [['SolarEdge Technologies SE 7600A-US (240V)'], ['SolarEdge Technologies SE 7600A-US (240V)'], ['SolarEdge Technologies SE 10000A-US (240V)'], ['SolarEdge Technologies SE 3800A-US (240V)'], ['SolarEdge Technologies SE 3800A-US (240V)'], ['SolarEdge Technologies SE3000H-US'], ['SolarEdge Technologies SE3000H-US']]
# <type 'list'>
# <type 'list'>
# <type 'list'>
# <type 'list'>
# <type 'list'>
# <type 'list'>
# <type 'list'>
#   Milestone         Project_Name  \
# 0       NTP   Thompson - 3108301
# 1       NTP   Thompson - 3108301
# 2       NTP      Black - 2908998
# 3       NTP  Rodriguez - 3131578
# 4       NTP  Rodriguez - 3131578
# 5       NTP    Baldwin - 3021807
# 6       NTP    Baldwin - 3021807
#
#                                        Error Message  SGVTY_Account_Number  \
# 0            Tranche Name in Re-Assessment/On-Deck;                3108301
# 1            Tranche Name in Re-Assessment/On-Deck;                3108301
# 2          Mismatch between LSC and SV4B Equipment;                2908998
# 3  LSC Doc Status is not Fully Executed or Approv...               3131578
# 4  LSC Doc Status is not Fully Executed or Approv...               3131578
# 5                                                                  3021807
# 6                                                                  3021807
#
#   Last_Name Installation_Address Installation_City  Installation_Zip_Code  \
# 0  Thompson         56 Henrys Rd          Brewster                   2631
# 1  Thompson         56 Henrys Rd          Brewster                   2631
# 2     Black       323 Via Napoli     Cathedral Cty                  92234
# 3      None        12 Rebecca Dr        Middletown                  10940
# 4      None        12 Rebecca Dr        Middletown                  10940
# 5   Baldwin        48 Norway Ave        Wilmington                  19804
# 6   Baldwin        48 Norway Ave        Wilmington                  19804
#
#   Installation_State Region       ...                   SV4B System  \
# 0                 MA    ALL       ...        SG285-29 SV1_FiOps Fix
# 1                 MA    ALL       ...        SG285-29 SV1_FiOps Fix
# 2                 CA    SCE       ...                  SG255-45 SV2
# 3                 NY   None       ...                  SG255-20 SV2
# 4                 NY   None       ...                  SG255-20 SV2
# 5                 DE    ALL       ...         SG285-9 SV2_Fiops Fix
# 6                 DE    ALL       ...         SG285-9 SV2_Fiops Fix
#
#   SV4B Contract Status PG System Size LSC System Size   Tranche Name  \
# 0       Contract Valid          8.265           8.265  Re-Assessment
# 1       Contract Valid          8.265           8.265  Re-Assessment
# 2       Contract Valid         11.700          11.700        On Deck
# 3       Contract Valid            NaN           5.100             K2
# 4       Contract Valid            NaN           5.100             K2
# 5       Contract Valid          2.565           2.565             SR
# 6       Contract Valid          2.565           2.565             SR
#
#    Tranche Status                                  AWE Case  AWE Case Status  \
# 0       Projected  40420 - Initial Interconnection Approval           Closed
# 1       Projected                   50610 - Design Revision           Closed
# 2       Projected                   50610 - Design Revision           Closed
# 3       Projected  40420 - Initial Interconnection Approval       Actionable
# 4       Projected                   50610 - Design Revision           Closed
# 5       Projected  40420 - Initial Interconnection Approval           Closed
# 6       Projected                   50610 - Design Revision           Closed
#
#   Auto-Inter. Geo AHJ Auto-Inter.
# 0              No            None
# 1              No            None
# 2              No              No
# 3              No            None
# 4              No            None
# 5              No            None
# 6              No            None
#
# [7 rows x 71 columns]
# File formatted and created in 0.2030 seconds
# Please find the created file in the following path:
# C:\Users\nseelam/Desktop/NeeAmmaNTP.xlsx
#
#
# Done! Directing back to Portal Menu
#
#
# Portals Menu:
# 1. Kina Milestone Submission
# 2. Data Upload File Creation
# 3. Exit
#
#
# Please enter the number associated with a task to proceed: 2
#
#
# Welcome to the Kina Data Upload Portal
# Currently this process is limited to creating Data Upload files for uploading date values for Milestone.
#
#
# Please enter the date value to upload, in the following format: yyyy-mm-dd6666-44-33
# Please enter Project Account Numbers seperated by a ',' for which this Data Upload Sheet is being created.  2970102,	    2490621,	    3094752,	    2235288,	    3155619
# Please select a Milestone
# 1. CAC
# 2. NTP
# 3. M1
# 4. M2
# 5. M3
# Please enter the number associated with the Milestone: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-36cd4a92c203> in <module>()
#      42             Portals.Kina_Submission_Portal(cnx)
#      43         if number == 2:
# ---> 44             Portals.Kina_Upload_Portal(cnx)
#      45         if number == 3:
#      46             print 'Exitting...'
#
# C:\Box Sync\nseelam\My Documents\Python Scripts\FPFE Scripts\FiOps_Portals.pyc in Kina_Upload_Portal(cnx)
#     219
#     220     if milestoneInput == 2:
# --> 221         query = NTP.NTPUpload()
#     222         path = NTP.NTPUploadPath()
#     223
#
# TypeError: NTPUpload() takes exactly 2 arguments (0 given)
